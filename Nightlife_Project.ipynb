# %%
#data with faker

# !pip install faker
import random
import faker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: faker in /usr/local/lib/python3.7/dist-packages (13.12.0)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (4.2.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
import pandas as pd
import datetime
from faker import Faker
fake_tr = Faker("tr_TR")
fake_en = Faker()
genress = ["r&b", "metal", "rock", "techno", "pop", "electronic", "blues", "jazz", "punk"]
provinces = ["taksim", "beşiktaş", "kadıköy", "beyoğlu", "levent", "bebek"]
province = []
venue = []
genreee = []
for i in range(500):
  venue.append(fake_en.domain_word())
  genreee.append(random.choice(genress))
  province.append(random.choice(provinces))

# %%
import re

# %%
f1 = open("artist_data.csv", "r")
artist = []
for celeb in f1:
  celeb_pp = str(celeb).lower()
  celeb_pp = re.sub("\n", "", celeb_pp)
  artist.append(celeb_pp)
artist[:10]
# Out:
# ['röyksopp',
#  'thievery corporation',
#  'dillon francis',
#  'dubloadz',
#  'what so not',
#  'axel boman',
#  'jordan comolli',
#  'hraach',
#  'kayzo',
#  'shlump']

# %%
artist_genre_dict[""]
# Out:
# 'alternative'

# %%
f2 = open("genre_data.csv", "r")
genre = []
for gen in f2:
  genre_pp = str(gen).lower()
  genre_pp = re.sub("\n", "", genre_pp)
  genre.append(genre_pp)
genre[:10]
# Out:
# ['electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic',
#  'electronic']

# %%
artist_genre_dict = dict(zip(artist, genre))

# %%
from pandas._libs import index
fake_data = {"genre": genreee, "province":province}
nightlife_data = pd.DataFrame(fake_data, index=venue)

nightlife_data[:20]
# Out:
#                        genre  province
# williamson               pop   kadıköy
# hebert-adams      electronic  beşiktaş
# morris-rios           techno   beyoğlu
# collins-mitchell         pop    levent
# miller                   pop    levent
# brown                    r&b   beyoğlu
# rivera                 blues    taksim
# ward                     r&b   beyoğlu
# robinson-evans        techno     bebek
# stevens-reeves         metal  beşiktaş
# castillo-cooper        blues  beşiktaş
# powers-kelley            pop    taksim
# hall-figueroa     electronic   kadıköy
# thompson              techno    taksim
# nguyen                  rock    levent
# powell                   r&b   beyoğlu
# wyatt                    pop  beşiktaş
# austin                 blues   kadıköy
# gallagher                r&b   kadıköy
# ramos                  blues  beşiktaş

# %%
pip install wit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wit in /usr/local/lib/python3.7/dist-packages (6.0.1)
# Requirement already satisfied: requests>=0.8.8 in /usr/local/lib/python3.7/dist-packages (from wit) (2.23.0)
# Requirement already satisfied: prompt-toolkit in /usr/local/lib/python3.7/dist-packages (from wit) (1.0.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=0.8.8->wit) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=0.8.8->wit) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=0.8.8->wit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=0.8.8->wit) (1.24.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit->wit) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit->wit) (1.15.0)

# %%
from wit import Wit
access_token = "5O6MM3BQBVCZHYIV5OMCFPDOO3NTH3AG"
person = Wit(access_token)
person.message('Where can I listen to R&B in Taksim?')
# Out:
# {'entities': {'genre:genre': [{'body': 'R&B',
#     'confidence': 1,
#     'end': 25,
#     'entities': [],
#     'id': '530474465436146',
#     'name': 'genre',
#     'role': 'genre',
#     'start': 22,
#     'type': 'value',
#     'value': 'r&b'}],
#   'province:province': [{'body': 'Taksim',
#     'confidence': 0.9995,
#     'end': 35,
#     'entities': [],
#     'id': '721137735598997',
#     'name': 'province',
#     'role': 'province',
#     'start': 29,
#     'type': 'value',
#     'value': 'Taksim'}]},
#  'intents': [],
#  'text': 'Where can I listen to R&B in Taksim?',
#  'traits': {}}

# %%
#nightlife_data.loc[["cook"], ["genre"]]

# %%
def find_genre(place):
  """Finds the genre of a venue"""
  place = place.lower()
  return nightlife_data.loc[[place], ["genre"]]

# %%
def find_venue(string):
  """Finds venues given genre or province"""
  string = string.lower()
  if string in genress:
    return nightlife_data.loc[nightlife_data["genre"] == string]
  elif string in provinces:
    return nightlife_data.loc[nightlife_data["province"] == string]

# %%
def find_venue_gp(string1, string2):
  """Finds venues given genre and province"""
  string1 = string1.lower()
  string2 = string2.lower()
  if string1 in genress and string2 in provinces:
    return nightlife_data.loc[(nightlife_data["genre"] == string1) & (nightlife_data["province"] == string2)]
  """
  if string1 in genress:
    return nightlife_data.loc[nightlife_data["genre"] == string1]
  if string2 in provinces:
    return [nightlife_data["province"] == string2]
  """

# %%
find_venue_gp("rock", "levent")
# Out:
# rock levent
#                  genre province
# nguyen            rock   levent
# fritz-andersen    rock   levent
# brown             rock   levent
# hogan-gomez       rock   levent
# simon             rock   levent
# hess-ellis        rock   levent
# fuentes           rock   levent
# roy               rock   levent
# daniels-martinez  rock   levent
# morris            rock   levent
# gonzalez          rock   levent

# %%
find_venue("pop")
# Out:
#                   genre  province
# williamson          pop   kadıköy
# collins-mitchell    pop    levent
# miller              pop    levent
# powers-kelley       pop    taksim
# wyatt               pop  beşiktaş
# swanson             pop    taksim
# perry               pop    levent
# snyder-hill         pop   kadıköy
# navarro             pop   beyoğlu
# mason               pop    levent
# valdez-frazier      pop   kadıköy
# fox                 pop    taksim
# mitchell-anderson   pop    levent
# fisher-ward         pop    levent
# ramos               pop   kadıköy
# benson              pop    taksim
# mendoza             pop   kadıköy
# johnson-simpson     pop    taksim
# cook-matthews       pop   beyoğlu
# beck                pop  beşiktaş
# welch-jefferson     pop  beşiktaş
# diaz                pop   kadıköy
# gonzalez            pop   kadıköy
# gibson              pop  beşiktaş
# cook                pop   beyoğlu
# campbell            pop   beyoğlu
# mendez              pop  beşiktaş
# williams            pop     bebek
# stewart             pop    taksim
# lawson-brown        pop   beyoğlu
# snyder              pop     bebek
# martin              pop  beşiktaş
# cook                pop   kadıköy
# duran-rodriguez     pop    levent
# yang                pop  beşiktaş
# rios                pop   beyoğlu
# jones               pop    levent
# avila               pop    taksim
# erickson            pop    taksim
# patel               pop     bebek
# brown               pop  beşiktaş
# evans-davila        pop     bebek
# henderson-adams     pop   kadıköy
# jackson-gomez       pop    levent
# garcia-marshall     pop   kadıköy
# romero              pop   beyoğlu
# russell-gonzales    pop   kadıköy
# wright              pop    taksim
# roberts             pop   kadıköy
# tanner              pop   kadıköy
# powell              pop    taksim
# cruz                pop  beşiktaş
# smith               pop    taksim
# newman              pop     bebek

# %%
def InputAnalysis(text):
  """Finds the province and genre from the wit.ai output"""
  resp = person.message(text)
  if len(resp["entities"]) == 2:
    entity0 = list(resp["entities"])[0]
    value0 = resp["entities"][entity0][0]["value"]
    entity0 = re.sub(r"\w+:", "", entity0)
    entity1 = list(resp["entities"])[1]
    value1 = resp["entities"][entity1][0]["value"]
    entity1 = re.sub(r"\w+:", "", entity1)
    return ([entity0, value0, entity1, value1])
  elif len(resp["entities"]) == 1:
    entity0 = list(resp["entities"])[0]
    value0 = resp["entities"][entity0][0]["value"]
    entity0 = re.sub(r"\w+:", "", entity0)
    return ([entity0, value0])
InputAnalysis('Where can I listen rnb?')
# Out:
# ['genre', 'r&b']

# %%
message = "I want to listen rock in beşiktaş"
entity0, value0, entity1, value1 = InputAnalysis(message)
# Out:
# {'province:province': [{'id': '721137735598997', 'name': 'province', 'role': 'province', 'start': 25, 'end': 33, 'body': 'beşiktaş', 'confidence': 1, 'entities': [], 'value': 'Beşiktaş', 'type': 'value'}], 'genre:genre': [{'id': '530474465436146', 'name': 'genre', 'role': 'genre', 'start': 17, 'end': 21, 'body': 'rock', 'confidence': 1, 'entities': [], 'value': 'rock', 'type': 'value'}]}

# %%
InputAnalysis("rnb in taksim")
# Out:
# {'province:province': [{'id': '721137735598997', 'name': 'province', 'role': 'province', 'start': 7, 'end': 13, 'body': 'taksim', 'confidence': 0.9995, 'entities': [], 'value': 'Taksim', 'type': 'value'}], 'genre:genre': [{'id': '530474465436146', 'name': 'genre', 'role': 'genre', 'start': 0, 'end': 3, 'body': 'rnb', 'confidence': 1, 'entities': [], 'value': 'r&b', 'type': 'value'}]}
# ('province', 'Taksim', 'genre', 'r&b')

# %%
find_venue_gp(value1, value0)
# Out:
# rock beşiktaş
#                 genre  province
# graham           rock  beşiktaş
# benson           rock  beşiktaş
# schwartz         rock  beşiktaş
# mckay            rock  beşiktaş
# smith            rock  beşiktaş
# harrison-castro  rock  beşiktaş
# peterson         rock  beşiktaş
# patterson        rock  beşiktaş
# gordon           rock  beşiktaş
# hale             rock  beşiktaş
# anderson         rock  beşiktaş

# %%
def NightBot(text):
  """bütün fonksiyonları birleştir"""
  returnlist = InputAnalysis(text)
  if len(returnlist) == 4:
    entity0, value0, entity1, value1 = InputAnalysis(text)
    result = find_venue_gp(value1, value0)
    bars = ",".join([str(i) for i in result.index.values])
    print(f"You can listen to {value1} in {value0} in these bars: {bars}")
  elif len(returnlist) == 2:
    entity0, value0 = InputAnalysis(text)
    result = find_venue(value0)
    bars = ",".join([str(i) for i in result.index.values])
    if entity0 =="province":
      print(f"These are the bars in {value0}: {bars}")
    else:
      print(f"You can listen to {value0} in these bars: {bars}")
